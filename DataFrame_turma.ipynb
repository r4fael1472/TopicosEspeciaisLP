# %%
#Criando a tabela

nomes = ['Abel', 'Ana','Bianca','Peter', 'Rafael', 'Caio', 'Thomas', 'Joaquin', 'Marcus', 'Matheus']
materias = ['LP1', 'LP2', 'AED1','SO', 'LP3', 'AED2', 'Web0', 'Web1', 'Calc1', 'Calc2']


import pandas as pd
import numpy as np

lista_nomes = []
lista_materias = []
lista_notas = []

for nome in nomes:
    num_materias = np.random.randint(3,11)
    materias_escolhidas = np.random.choice(materias, size=num_materias, replace=False)
    for materia in materias_escolhidas:
        nota = np.round(np.random.random()*10,1)
        lista_nomes.append(nome)
        lista_materias.append(materia)
        lista_notas.append(nota)

#Criando Dicionario

turma = {'nomes': lista_nomes, 'materias' : lista_materias, 'notas' : lista_notas}
df_turma = pd.DataFrame(turma, columns=['nomes', 'materias', 'notas'])

print(df_turma)
# Out:
#       nomes materias  notas
# 0      Abel      LP3    2.1
# 1      Abel    Calc2    2.2
# 2      Abel     Web1    8.1
# 3      Abel      LP2    0.1
# 4      Abel      LP1    5.3
# 5      Abel     Web0    8.3
# 6      Abel    Calc1    3.2
# 7      Abel       SO    9.6
# 8      Abel     AED2    0.6
# 9       Ana      LP3    4.9
# 10      Ana     AED2    9.3
# 11      Ana     Web1    7.2
# 12      Ana       SO    6.5
# 13      Ana     AED1    3.7
# 14      Ana    Calc2    5.9
# 15      Ana    Calc1    1.8
# 16   Bianca     Web1    1.5
# 17   Bianca     AED1    1.1
# 18   Bianca     AED2    3.4
# 19   Bianca      LP1    2.4
# 20   Bianca      LP3    6.4
# 21   Bianca     Web0    8.5
# 22   Bianca      LP2    9.3
# 23   Bianca       SO    6.3
# 24   Bianca    Calc1    7.4
# 25    Peter      LP3    7.2
# 26    Peter      LP2    4.6
# 27    Peter     Web0    2.5
# 28    Peter    Calc1    0.9
# 29   Rafael     AED2    4.9
# 30   Rafael    Calc1    4.0
# 31   Rafael    Calc2    9.9
# 32   Rafael      LP1    3.4
# 33   Rafael       SO    8.7
# 34   Rafael     AED1    9.8
# 35     Caio      LP1    0.2
# 36     Caio     AED2    6.3
# 37     Caio    Calc2    5.3
# 38   Thomas    Calc2    2.9
# 39   Thomas    Calc1    0.8
# 40   Thomas       SO    8.2
# 41   Thomas      LP2    0.0
# 42   Thomas     AED2    2.3
# 43   Thomas     Web0    3.9
# 44  Joaquin      LP3    3.2
# 45  Joaquin      LP2    6.1
# 46  Joaquin    Calc2    0.3
# 47  Joaquin      LP1    0.6
# 48   Marcus     AED2    5.0
# 49   Marcus    Calc2    7.0
# 50   Marcus      LP3    9.9
# 51   Marcus    Calc1    7.2
# 52  Matheus     AED1    4.5
# 53  Matheus    Calc2    4.1
# 54  Matheus    Calc1    8.9
# 55  Matheus     Web0    0.6
# 56  Matheus     AED2    1.6
# 57  Matheus     Web1    7.3
# 58  Matheus       SO    1.4
# 59  Matheus      LP1    3.0
